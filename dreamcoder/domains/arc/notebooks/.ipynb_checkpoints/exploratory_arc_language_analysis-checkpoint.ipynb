# %% [markdown]
# *What this is*: exploratory analysis for language data on ARC and ground truth programs.
#
#  Simple baselines to run:
# - Unigram model over the training data; give the likelihood of the programs under the resulting model.
# - Linear/simple prediction model from NL encoder vector to -> over the unigrams.
# - Dot product similarities between NL encoder and the unigrams.

# %%
import os
import numpy as np
import pandas as pd

# %% [markdown]
# ### Data exploration

# %%
DATA_DIRECTORY = "/Users/catwong/Desktop/zyzzyva/code/ec_arc/data/arc/"
LANGUAGE_DATA_FILE = "all_unique_programs.csv"

language_file = os.path.join(DATA_DIRECTORY, LANGUAGE_DATA_FILE)

# T5 is good. Just using the encoder. Or ROBERTA.

# %%
import csv

task_to_data = dict()
with open(language_file, 'r') as f:
    reader = csv.DictReader(f)
    for row in reader:
        task_name, program, nl_0 = row[""], row['program'], row['nl_0']
        if task_name not in task_to_data:
            task_to_data[task_name] = (program, nl_0)

# %%
def tokenize_program(program):
    replace_tokens = ["lambda", "_", ")", "(", "false", "true"]
    for replace_token in replace_tokens:
        program = program.replace(replace_token, " ")
    program = " ".join(program.split())
    return program
    
for task_name in task_to_data:
    program, nl_0 = task_to_data[task_name]
    tokenized = tokenize_program(program)
    print(f"{nl_0}")
    print("\n")
    print(f"{tokenized}")
    print("\n\n")
# Out:
# copy paste the pattern in each corner the pattern on the bottom s flip s parallel to the top
#
#
# to min grid reflect remove black b move reflect remove black b move reflect grid to block $0 3 south 3 east
#
#
#
# copy the input grid find any shape s outside of the border which are exactly the same shape and orientation as the shape inside of the grey border turn that shape grey do not change the colored shape inside the grey border or any shape s outside of the grey border which do not have the same orientation and shape as the one inside the border
#
#
# # to min grid $0 replace color grid to block $0 nth primary color wrap block remove black b move grid to block $0 3 east invisible 3 grey
#
#
#
# create a left right mirror image of the input
#
#
# to min grid reflect grid to block $0
#
#
#
# make the grid the same size as the shape and the two color s are just like in the shape
#
#
# to min grid first of sorted object list find same color blocks $0 get num tiles remove color $0 blue
#
#
#
# change the pattern to match the one colored square at the bottom and fill in the one square at the bottom to black
#
#
# to original grid overlay fill color merge blocks find blocks by color $0 nth primary color # remove black b grid to block $0 $0 0 get tile color get block center remove color # remove color # remove black b grid to block $0 $0 nth primary color grid to block $0 1 $0 blue
#
#
#
# follow the insturction
#
#
# to min grid remove color grid to block $0 blue
#
#
#
# copy the pattern as you see it on the bottom half of the grid into 3 by 4 once done flip the pattern up to the top half of the 3 by 4 grid
#
#
# to min grid move reflect grid to block $0 3 north
#
#
#
# count how many row s each object contain s and move it up that same amount of row s
#
#
# blocks to original grid map blocks find same color blocks $0 move $0 get height $0 north
#
#
#
# apply the grid size and fill the color s
#
#
# to min grid grow grid to block $0 1
#
#
#
# copy the figure two time s in that grid size
#
#
# to min grid duplicate box block remove black b grid to block $0 east 1
#
#
#
# compare the square s in the top and bottom 4 by 4 square if they match both black or both color make the output square black if they do not match make the output square green
#
#
# overlap split blocks split grid $0 color logical $0 $1 green lxor
#
#
#
# blue block add
#
#
# to original grid overlay replace color merge blocks find same color blocks $0 black blue
#
#
#
# copy the input if two block s acros s from each other are the same color fill in the rest of that horizontal row with that color don t do anything with the block s acros s from each other that are different color s
#
#
# blocks to original grid map tiles find tiles by black b $0 extend towards until edge $0 east
#
#
#
# join the color
#
#
# # blocks to original grid map tiles find tiles by black b $0 $1 move until overlaps block $0 first of sorted object list # filter blocks find same color blocks $0 is symmetrical $0 $1 get num tiles $0 $0
#
#
#
# copy the input grid then connect the 2 by 2 green square to any and all other colored square s which you can reach with a straight line use the color of the square to which you are connecting the 2 by 2 green square fill in all of the black square s between that square and the 2 by 2 green square leave the rest of the grid including any colored square you can t reach with a straight line as they are
#
#
# blocks to original grid map tiles find tiles by black b $0 extend until touches block $0 first of sorted object list find same color blocks $1 get num tiles $0
#
#
#
# copy the pattern that is a different color
#
#
# to min grid remove black b remove color grid to block $0 nth primary color grid to block $0 1
#
#
#
# copy the input 3 by 3 multi colored shape ontop of the gray square this square comprise s the middle of the 3 by 3 copy
#
#
# blocks to original grid map tiles find tiles by black b $0 center block on tile first of sorted object list find blocks by inferred b $1 get num tiles $0 $0
#
#
#
# surround each grey box with blue
#
#
# to original grid overlay wrap block remove black b grid to block $0 blue
#
#
#
# copy only the biggest shape into the output grid
#
#
# to min grid first of sorted object list find same color blocks $0 get num tiles $0
#
#
#
# repeat the colored area that include s a grey square but do not include the gray square
#
#
# to min grid remove color first of sorted object list find blocks by inferred b $0 get num tiles $0 grey
#
#
#
# change position for every grid
#
#
# to min grid reflect reflect grid to block $0
#
#
#
# determine what color is used the most in the input grid and make the entire output grid that color
#
#
# to min grid fill color grid to block $0 nth primary color grid to block $0 0
#
#
#
# consider the long input as two section s as 4 by 4 grid s consider that the two section s as one then the leave that black space s as black then point the colored block s as green
#
#
# overlap split blocks split grid $0 color logical $0 $1 green lor
#
#
#
# change the yellow grid s into grey one
#
#
# to min grid replace color grid to block $0 orange grey
#
#
#
# copy the input image to the other half but in opposite position
#
#
# to min grid move reflect grid to block $0 3 east
#
#
#
# overlapping the two pattern s if the color s are the same then it is colored black if they are different then they are colored in a different color
#
#
# # overlap split blocks $0 color logical $0 $1 $3 $4 lxor green split grid $0 is interior get block center grid to block $0
#
#
#
# change every other square on each of the diagonal line s to yellow
#
#
# # blocks to original grid map tiles find tiles by black b $0 $1 fill snakewise extend towards until edge $0 north west make colorpair invisible yellow $0
#
#
#
# copy and mirror the colored object
#
#
# to min grid reflect remove black b grid to block $0 negate boolean
#
#
#
# 9 square s that go all around it into blue
#
#
# blocks to original grid map tiles find tiles by black b $0 fill color wrap block remove black b grid to block $1 blue blue
#
#
#
# fill in the area of the large section with red to make a rectangular section background remain the same color
#
#
# to original grid overlay replace color merge blocks find same color blocks $0 black red
#
#
#
# change the grid size with the colored object with the smallest area and fill the same color
#
#
# to min grid first of sorted object list find same color blocks $0 get height $0
#
#
#
# copy the largest squared border including colored square s inside but make all colored square s the same color as interior square s
#
#
# to min grid replace color first of sorted object list find same color blocks $0 get num tiles $0 nth primary color remove black b first of sorted object list find same color blocks $0 get num tiles $0 0 nth primary color remove black b first of sorted object list find same color blocks $0 get num tiles $0 0
#
#
#
# any green colored block s that are more than 2 connected block s 1 by 2 2 by 1 2 by 2 or other shape s should be changed to light blue
#
#
# to original grid overlay filter block tiles fill color remove black b grid to block $0 teal negate boolean tile overlaps block $0 merge blocks tiles to blocks find tiles by black b $1
#
#
#
# complete the square s using the color orange
#
#
# to original grid overlay replace color merge blocks find same color blocks $0 black orange
#
#
#
# copy and paste the biggest object and the black boxe s that make up the rectangle
#
#
# to min grid first of sorted object list find same color blocks $0 get num tiles $0
#
#
#
# color the inside of each colored area with light blue leave the outside of the colored shape s the example color one cube deep all the way around
#
#
# blocks to original grid map blocks find blocks by black b $0 fill color filter block tiles $0 is interior $0 teal
#
#
#
# make input pattern as center for output and color s should be same the adjacent color s are also same all four corner color s should be black
#
#
# to min grid wrap block grid to block $0 black
#
#
#
# zoom into the different colored center block from the input grid and make it the only colored block
#
#
# to min grid filter block tiles remove black b grid to block $0 is interior $0
#
#
#
# copy one of the figure s and just that figure
#
#
# blocks to min grid filter blocks find same color blocks $0 is tile $0
#
#
#
# reflect down side to top
#
#
# to original grid overlay remove black b reflect grid to block $0
#
#
#
# count the number of copie s of each shape zoom in on the shape with the most copie s
#
#
# to min grid first of sorted object list find same color blocks $0 1
#
#
#
# mirror the exact pattern of the 3 by 3 grid at the bottom
#
#
# to min grid move reflect grid to block $0 3 south
#
#
#
# copy one half of the input
#
#
# # to min grid first of sorted object list $0 get num tiles $0 $1 splitblocks to blocks split grid $0 is symmetrical merge blocks # filter blocks find same color blocks $0 is symmetrical $0 $0
#
#
#
# flip the input grid vertically
#
#
# to min grid reflect grid to block $0
#
#
#
# imagine taking out the line grey block s and sliding the left half over until it line s up with the right side if two blue block s are on top of each other the block become s red otherwise the block is black
#
#
# overlap split blocks split grid $0 color logical $0 $1 red land
#
#
#
# fill the same color by 4 by 4 grid size
#
#
# to min grid wrap block grow remove black b grid to block $0 1 invisible
#
#
#
# fill the black spot s with the exact same pattern that need to be filled in the original grid
#
#
# to min grid filter block tiles remove black b reflect grid to block $0 negate boolean tile overlaps block $0 remove black b grid to block $1
#
#
#
# make black square s in the square
#
#
# blocks to original grid map blocks find same color blocks $0 filter block tiles $0 is exterior $0
#
#
#
# copy the rectangular shape with the most red square s exactly
#
#
# # to min grid first of sorted object list find blocks by black b $0 $1 get num tiles remove color remove color $0 blue teal $0
#
#
#
# connect the magenta boxe s except 1 magenta box look like l shape 2 line shape
#
#
# blocks to original grid map tiles find tiles by black b $0 extend until touches block $0 first of sorted object list find same color blocks $1 get num tiles extend until touches block $1 $0
#
#
#
# you have to you need to make sure the colored image is exactly
#
#
# to min grid remove black b grid to block $0
#
#
#
# draw a blue border around each red square so it will look like a 3 by 3 blue square with a red square in the center but if the red square is in the corner just fill in 3 blue block s around it
#
#
# # blocks to original grid map tiles find tiles by black b $0 $1 wrap block merge blocks find blocks by color $1 red blue $0
#
#
#
# copy the input grid and then mirror the colored line s on the other end of the grid
#
#
# to original grid overlay remove black b reflect reflect grid to block $0
#
#
#
# copy the colored shape but make it twice the size as the input shape
#
#
# to min grid grow merge blocks find blocks by black b $0 1
#
#
#
# replace all the purple square s with red
#
#
# to min grid replace color grid to block $0 pink red
#
#
#
# copy colored box pattern on left onto each blue square
#
#
# # blocks to original grid map tiles find tiles by black b $0 $1 center block on tile remove color # remove color # remove black b grid to block $0 $0 nth primary color grid to block $0 1 $1 blue $0 $0
#
#
#
# keep the color with the most square s and everything else should be gray
#
#
# to original grid overlay fill color merge blocks find blocks by inferred b $0 grey
#
#
#
# copy the same color s in the same position for every single grid in the input it should be changed to a 3 by 3 of color each in the output
#
#
# to min grid grow grid to block $0 2
#
#
#
# fill each area of the output grid with the same color of the input grid
#
#
# to min grid grow grid to block $0 get num tiles remove color remove black b grid to block $0 nth primary color grid to block $0 1
#
#
#
# copy the shape with the light blue dot but replace the light blue dot with the shape color
#
#
# to min grid fill color merge blocks filter blocks find blocks by black b $0 has color $0 teal nth primary color merge blocks filter blocks find blocks by black b $0 has color $0 teal 0
#
#
#
# create a light blue border around the grid so any square s that are touching the edge s are filled in with light blue the rest of the square s inside the light blue border remain black
#
#
# to min grid filter block tiles fill color grid to block $0 teal is exterior $0
#
#
#
# copy the entire small square grid without change in the pattern or the color s along with the border
#
#
# to min grid first of sorted object list filter blocks find same color blocks $0 is symmetrical $0 get num tiles $0
#
#
#
# color in the colored square s with blue that stand by themselve s or have no side connect with other square s
#
#
# to original grid overlay fill color merge blocks tiles to blocks find tiles by black b $0 blue
#
#
#
# drop 3 blue cell down one cell as a group
#
#
# to original grid overlay move grid to block $0 1 south
#
#
#
# copy the grid and reflect it on the other half
#
#
# to min grid move reflect remove black b grid to block $0 3 east
#
#
#
# change the dark blue boxe s to green boxe s where they cover part s of the rectangle created by the light blue boxe s once changed the rectangle shape should be clear with no dark blue boxe s within it s border s
#
#
# # to original grid overlay fill color $0 $1 green # remove color box block $0 teal remove color # remove black b grid to block $0 $0 blue
#
#
#
# fill in the black under any color with the same color
#
#
# blocks to original grid map tiles find tiles by black b $0 extend towards until $0 south touches boundary tile to block $0 south
#
#
#
# replicate any of the 4 by 4 color pattern
#
#
# to min grid first of sorted object list find same color blocks $0 get num tiles $0 negate boolean has color grid to block $0 blue
#
#
#
# imagine that the entire grid ha s been flipped both horizontally and vertically once you picture it you can create the output grid
#
#
# to min grid reflect reflect remove color grid to block $0 yellow
#
#
#
# changed the grid and the color
#
#
# blocks to original grid map blocks filter blocks find blocks by color $0 black negate boolean touches any boundary $0 fill color $0 blue
#
#
#
# keep the vertical middle line of square s the same and color the rest of the square s black
#
#
# to min grid fill color merge blocks splitblocks to blocks split grid $0 nth primary color grid to block $0 0
#
#
#
# copy the 3 by 3 square from the input grid that ha s the most blue pixel s
#
#
# to min grid first of sorted object list find blocks by color $0 blue get num tiles $0
#
#
#
# color in the center of each gray square red but make sure you leave a 1 square gray border around it so if it s a 5 by 5 gray square you would color a red 3 by 3 square in side it leaving a gray border around the red square
#
#
# to original grid overlay filter block tiles fill color merge blocks find blocks by inferred b $0 red is interior $0
#
#
#
# copy the pattern exactly to the new empty section there should be two of the same pattern side by side
#
#
# to min grid duplicate grid to block $0 east 1
#
#
#
# select the quadrant with the different colored square then copy and paste the quadrant as the output
#
#
# # to min grid first of sorted object list $0 get num tiles $0 $1 find blocks by color $0 nth primary color # remove black b grid to block $0 $0 0
#
#
#
# copy the input grid into the top of the new output grid then you will turn the input grid upside down and copy it in the bottom of the output grid this will create a mirror image top to bottom
#
#
# # to min grid move reflect grid to block $2 $1 3 $0 $0 is interior get block center grid to block $0 south
#
#
#
# copy those specific shape s one block below and change the color to red
#
#
# to original grid overlay move replace color grid to block $0 teal red 1 south
#
#
#
# change the yellow square s to finish the pattern
#
#
# to min grid reflect remove color grid to block $0 yellow
#
#
#
# fill in the hole s of the boxe s with green then black out the outline s of the boxe s
#
#
# to original grid overlay filter block tiles fill color merge blocks find same color blocks $0 green is interior $0
#
#
#
# changed
#
#
# to min grid remove black b first of sorted object list find same color blocks $0 get num tiles $0
#
#
#
# copy the input grid then close and fill in the shape s so that they look a little like weird triangle s
#
#
# blocks to original grid map tiles find tiles by black b $0 extend until touches block $0 merge blocks tiles to blocks find tiles by black b $1
#
#
#
# copy and paste the left side of the input the yellow side onto the output grid then draw the green pattern on the output grid on top of the yellow do not copy and paste because the black will overwrite the yellow your output grid should now have green and yellow on a black background then recolor each green and yellow square pink so your output is only pink and black
#
#
# overlap split blocks split grid $0 color logical $0 $1 pink lor
#
#
#
#
#
#
# to min grid first of sorted object list find same color blocks $0 has color grid to block $0 red get num tiles $0

# %%
class DummyModel():
    def __init__(self):
        pass
    
    def fit(self, training_data):
        pass
    
    def evaluate_likelihood(self, language, ground_truth_program):
        return 0.0

def leave_one_out_evaluation(task_to_data, model):
    print(f"Running leave one out evaluation on {len(task_to_data)} tasks.")
    tasks_to_likelihoods = dict()
    for task in task_to_data:
        language, ground_truth_program = task_to_data[task]
        training_tasks = {t : d for t, d in task_to_data.items() if t != task}
        model.fit(training_tasks)
        likelihood = model.evaluate_likelihood(language, ground_truth_program)
        tasks_to_likelihoods[task] = likelihood
    print(f"Average likelihood: {np.mean(list(tasks_to_likelihoods.values()))}")
    return tasks_to_likelihoods
        

tasks_to_likelihoods = leave_one_out_evaluation(task_to_data, DummyModel())
# Out:
# Running leave one out evaluation on 83 tasks.
# Average likelihood: 0.0

# %% [markdown]
# ### Large language model and linear prediction baseline

# %% [markdown]
# TODO:
# - Encode the natural language to vector
# - Fit a linear decoder from the natural language vector to unigram predictions
# - Convert the unigram scores into a unigram grammar
# - Evaluate the likelihood of a ground truth program under the grammar
# - Training and evaluation loop: we should have a leave one out prediction.

# %% [markdown]
# ### Language encoding utilities

# %%
demo_task = '67e8384a.json'
demo_program, demo_language = task_to_data[demo_task]
print(demo_language)

from transformers import pipeline, T5Tokenizer, TFT5Model
T5_MODEL = 't5-small' # Source: https://huggingface.co/transformers/pretrained_models.html 
ROBERTA_MODEL = 'distilroberta-base'
T5 = 't5'

class LMUnigramPredictionLinear():
     def __init__(self, lm_model_name):
        self.lm_model_name = lm_model_name
        if T5 in self.lm_model_name:
            self.tokenizer = T5Tokenizer.from_pretrained(self.lm_model_name)
            self.t5_encoder_model = TFT5EncoderModel.from_pretrained(self.lm_model_name)
            self.featurizer = self._t5_featurizer_fn
        else:
            self.featurizer = pipeline('feature-extraction', self.lm_model_name)
            
    def _t5_featurizer_fn(self, language):
        input_ids = self.tokenizer(language, return_tensors="tf").input_ids  # Batch size 1
        return self.t5_encoder_model(input_ids)
    
    def _featurize_language(self, language):
        outputs = self.featurizer(language)
        return outputs

model = LMUnigramPredictionLinear(T5_MODEL)
outputs = model._featurize_language(demo_language)
# Out:
# copy paste the pattern in each corner the pattern on the bottom s flip s parallel to the top
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-35-10e2dfebdfb2> in <module>
#      26         return outputs
#      27
# ---> 28 model = LMUnigramPredictionLinear(T5_MODEL)
#      29 outputs = model._featurize_language(demo_language)
#
# <ipython-input-35-10e2dfebdfb2> in __init__(self, lm_model_name)
#      12         self.lm_model_name = lm_model_name
#      13         if T5 in self.lm_model_name:
# ---> 14             self.tokenizer = T5Tokenizer.from_pretrained(self.lm_model_name)
#      15             self.t5_encoder_model = TFT5EncoderModel.from_pretrained(self.lm_model_name)
#      16             self.featurizer = self._t5_featurizer_fn
#
# ~/.pyenv/versions/3.7.7/lib/python3.7/site-packages/transformers/utils/dummy_sentencepiece_objects.py in from_pretrained(self, *args, **kwargs)
#     126     @classmethod
#     127     def from_pretrained(self, *args, **kwargs):
# --> 128         requires_backends(self, ["sentencepiece"])
#     129
#     130
#
# ~/.pyenv/versions/3.7.7/lib/python3.7/site-packages/transformers/file_utils.py in requires_backends(obj, backends)
#     567     name = obj.__name__ if hasattr(obj, "__name__") else obj.__class__.__name__
#     568     if not all(BACKENDS_MAPPING[backend][0]() for backend in backends):
# --> 569         raise ImportError("".join([BACKENDS_MAPPING[backend][1].format(name) for backend in backends]))
#     570
#     571
#
# ImportError:
# T5Tokenizer requires the SentencePiece library but it was not found in your environment. Checkout the instructions on the
# installation page of its repo: https://github.com/google/sentencepiece#installation and follow the ones
# that match your environment.

# %%
# Out:
# 1
