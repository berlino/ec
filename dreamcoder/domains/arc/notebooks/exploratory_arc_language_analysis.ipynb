# %% [markdown]
# *What this is*: exploratory analysis for language data on ARC and ground truth programs.
#
#  Simple baselines to run:
# - Unigram model over the training data; give the likelihood of the programs under the resulting model.
# - Linear/simple prediction model from NL encoder vector to -> over the unigrams.
# - Dot product similarities between NL encoder and the unigrams.

# %%
import os
import numpy as np
import pandas as pd
import tensorflow as tf

# %% [markdown]
# ### Data exploration

# %%
DATA_DIRECTORY = "/Users/catwong/Desktop/zyzzyva/code/ec_arc/data/arc/"
LANGUAGE_DATA_FILE = "ManyProgramsPlusNlDescription.csv"

language_file = os.path.join(DATA_DIRECTORY, LANGUAGE_DATA_FILE)

# T5 is good. Just using the encoder. Or ROBERTA.

# %%
import csv

task_to_data = dict()
with open(language_file, 'r') as f:
    reader = csv.DictReader(f)
    for row in reader:
        task_name, program, language = row["taskName"], row['program'], row['nlDescription']
        if task_name in task_to_data:
            task_name += "_"
        task_to_data[task_name] = (program, language)

# %%
def tokenize_program(program):
    replace_tokens = ["lambda", "_", ")", "(", "false", "true"]
    for replace_token in replace_tokens:
        program = program.replace(replace_token, " ")
    program = " ".join(program.split())
    return program
    
for task_name in task_to_data:
    program, nl_0 = task_to_data[task_name]
    tokenized = tokenize_program(program)
    print(f"{nl_0}")
    print("\n")
    print(f"{tokenized}")
    print("\n\n")
# Out:
# look at both the left and right parts of the input grid. You will notice that the left and right parts are 3x3. For each square that is colored on both the left and right parts, color the output grid with red on the new 3x3.
#
#
# overlap split blocks split grid $0 color logical $0 $1 red land
#
#
#
# look at both the left and right parts of the input grid. You will notice that the left and right parts are 3x3. For each square that is colored on both the left and right parts, color the output grid with red on the new 3x3.
#
#
# overlap split blocks split grid $0 is tile grow grid to block $0 1 color logical $1 $0 red land
#
#
#
# make it the area that is a different color.
#
#
# to min grid remove black b remove color grid to block $0 nth primary color grid to block $0 1
#
#
#
# make it the area that is a different color.
#
#
# blocks to min grid find blocks by color $0 nth primary color grid to block $0 2
#
#
#
# you just need to make sure the colored image is exactly (top, bottom, left, right) in the new grid. No color change.
#
#
# to min grid remove black b grid to block $0
#
#
#
# you just need to make sure the colored image is exactly (top, bottom, left, right) in the new grid. No color change.
#
#
# to min grid remove black b grid to block $0 touches any boundary grid to block $0
#
#
#
# copy only the biggest shape into the output grid copy the small dense part copy the small dense part
#
#
# to min grid first of sorted object list find same color blocks $0 get num tiles $0
#
#
#
# copy only the biggest shape into the output grid copy the small dense part copy the small dense part
#
#
# to min grid first of sorted object list find same color blocks $0 get num tiles $0
#
#
#
# fill in the area above the four square base until you get to the top of the colored area
#
#
# blocks to original grid map tiles find tiles by black b $0 extend until touches block $0 merge blocks tiles to blocks find tiles by black b $1
#
#
#
# fill in the area above the four square base until you get to the top of the colored area
#
#
# blocks to original grid map tiles find tiles by black b $0 extend until touches block $0 replace color merge blocks tiles to blocks find tiles by black b $1 black red
#
#
#
# copy the input. If two blocks across from each other are the same color, fill in the rest of that horizontal row with that color. Don't do anything with the blocks across from each other that are different colors
#
#
# blocks to original grid map tiles find tiles by black b $0 extend towards until edge $0 east
#
#
#
# copy the input. If two blocks across from each other are the same color, fill in the rest of that horizontal row with that color. Don't do anything with the blocks across from each other that are different colors
#
#
# blocks to original grid map tiles find tiles by black b $0 extend towards until edge $0 east is tile fill color grid to block $0 nth primary color grid to block $0 0
#
#
#
# change the grid size with the colored object with the smallest area and fill the same color.
#
#
# to min grid first of sorted object list find same color blocks $0 get height $0
#
#
#
# change the grid size with the colored object with the smallest area and fill the same color.
#
#
# to min grid first of sorted object list find same color blocks $0 get width $0
#
#
#
# move all the blue color move down  by one grid
#
#
# to original grid overlay move grid to block $0 1 south
#
#
#
# move all the blue color move down  by one grid
#
#
# to original grid overlay remove black b move grid to block $0 1 south negate boolean
#
#
#
# copy the figure two times in that grid size.
#
#
# to min grid duplicate box block remove black b grid to block $0 east 1
#
#
#
# copy the figure two times in that grid size.
#
#
# to min grid filter block tiles remove black b move grid to block $0 3 east is exterior $0
#
#
#
# select the quadrant with the different colored square, then copy and paste the quadrant as the output.
#
#
# to min grid first of sorted object list find blocks by color $0 nth primary color grid to block $0 0 get num tiles $0
#
#
#
# select the quadrant with the different colored square, then copy and paste the quadrant as the output.
#
#
# to min grid first of sorted object list filter blocks find blocks by color $0 nth primary color grid to block $0 0 get num tiles remove color $0 nth primary color $0 2
#
#
#
# count the number of copies of each shape. Zoom in on the shape with the most copies.
#
#
# to min grid first of sorted object list find same color blocks $0 1
#
#
#
# count the number of copies of each shape. Zoom in on the shape with the most copies.
#
#
# to min grid first of sorted object list find same color blocks $0 4
#
#
#
# fill in the missing corners with a blue square.
#
#
# to original grid overlay replace color merge blocks find same color blocks $0 black blue
#
#
#
# fill in the missing corners with a blue square.
#
#
# to original grid overlay filter block tiles fill color merge blocks find same color blocks $0 nth primary color grid to block $0 2 negate boolean tile overlaps block $0 merge blocks find same color blocks $1
#
#
#
# Create the same pattern as the input, just rotated 180 degrees. Done.
#
#
# to min grid reflect reflect grid to block $0
#
#
#
# Create the same pattern as the input, just rotated 180 degrees. Done.
#
#
# to min grid reflect reflect grid to block $0 negate boolean
#
#
#
# surround each grey box with blue surround each of the grey boxes with a 3x3 blue border
#
#
# to original grid overlay wrap block remove black b grid to block $0 blue
#
#
#
# surround each grey box with blue surround each of the grey boxes with a 3x3 blue border
#
#
# to original grid overlay wrap block remove black b grid to block $0 blue negate boolean
#
#
#
# replace all colored blocks inside the rectangular shapes with black so there is only a colored outline of the shapes remove the center of the blocks with black and have a single block wide line for each square.
#
#
# blocks to original grid map blocks find same color blocks $0 filter block tiles $0 is exterior $0
#
#
#
# replace all colored blocks inside the rectangular shapes with black so there is only a colored outline of the shapes remove the center of the blocks with black and have a single block wide line for each square.
#
#
# to original grid overlay filter block tiles remove black b reflect reflect remove black b grid to block $0 is exterior $0
#
#
#
# repeat the colored area that includes a grey square, but don't include the grey square.
#
#
# to min grid remove color first of sorted object list find blocks by inferred b $0 get num tiles $0 grey
#
#
#
# repeat the colored area that includes a grey square, but don't include the grey square.
#
#
# to min grid remove color remove color first of sorted object list find blocks by inferred b $0 get num tiles $0 grey grey
#
#
#
# mirror the top pattern below.
#
#
# to original grid overlay remove black b reflect reflect grid to block $0
#
#
#
# mirror the top pattern below.
#
#
# to original grid overlay remove black b reflect reflect grid to block $0
#
#
#
# make input pattern as center for output and colors should be same. The adjacent colors are also same . all four corner colors should be black
#
#
# to min grid wrap block grid to block $0 black
#
#
#
# make input pattern as center for output and colors should be same. The adjacent colors are also same . all four corner colors should be black
#
#
# to min grid wrap block grid to block $0 black negate boolean
#
#
#
# copy the pattern as you see it on the bottom half of the grid into 3x4. Once done, flip the pattern up to the top half of the 3x4 grid.
#
#
# to min grid move reflect grid to block $0 3 north
#
#
#
# copy the pattern as you see it on the bottom half of the grid into 3x4. Once done, flip the pattern up to the top half of the 3x4 grid.
#
#
# to min grid remove black b move box block remove black b reflect grid to block $0 3 north
#
#
#
# color the inside of each colored area with light blue. Leave the outside of the colored shapes the example color one cube deep all the way around.
#
#
# blocks to original grid map blocks find blocks by black b $0 fill color filter block tiles $0 is interior $0 teal
#
#
#
# color the inside of each colored area with light blue. Leave the outside of the colored shapes the example color one cube deep all the way around.
#
#
# to original grid overlay filter block tiles fill color remove black b reflect reflect grid to block $0 teal is interior $0
#
#
#
# copy the shape with the light blue dot but replace the light blue dot with the shape color.
#
#
# to min grid fill color merge blocks filter blocks find blocks by black b $0 has color $0 teal nth primary color merge blocks filter blocks find blocks by black b $0 has color $0 teal 0
#
#
#
# decide how many rows the object has and move it up that same amount of rows.
#
#
# blocks to original grid map blocks find same color blocks $0 move $0 get height $0 north
#
#
#
# determine what color is used the most in the input grid and make the entire output grid that color. determine which color is used for the majority of the squares in the input grid, then use that color for the entire output grid.
#
#
# to min grid fill color grid to block $0 nth primary color grid to block $0 0
#
#
#
# determine what color is used the most in the input grid and make the entire output grid that color. determine which color is used for the majority of the squares in the input grid, then use that color for the entire output grid.
#
#
# to original grid overlay fill color box block remove black b grid to block $0 nth primary color grid to block $0 0
#
#
#
# keep the shapes in the same place, but fill the gaps in the shape with the color orange until they form squares
#
#
# to original grid overlay replace color merge blocks find same color blocks $0 black orange
#
#
#
# keep the shapes in the same place, but fill the gaps in the shape with the color orange until they form squares
#
#
# to original grid overlay filter block tiles fill color merge blocks find same color blocks $0 orange negate boolean tile overlaps block $0 remove black b move grid to block $1 3 south
#
#
#
# imagine that the entire grid has been flipped both horizontally and vertically. Once you picture it, you can create the output grid. imagine that the entire grid has been flipped both horizontally and vertically. Once you picture that you can create the output grid.
#
#
# to min grid reflect reflect remove color grid to block $0 yellow
#
#
#
# imagine that the entire grid has been flipped both horizontally and vertically. Once you picture it, you can create the output grid. imagine that the entire grid has been flipped both horizontally and vertically. Once you picture that you can create the output grid.
#
#
# to original grid overlay remove black b reflect reflect grid to block $0
#
#
#
# any green colored blocks that are more than 2 connected blocks (1x2, 2x1, 2x2, or other shapes) should be changed to light blue.
#
#
# to original grid overlay filter block tiles fill color remove black b grid to block $0 teal negate boolean tile overlaps block $0 merge blocks tiles to blocks find tiles by black b $1
#
#
#
# any green colored blocks that are more than 2 connected blocks (1x2, 2x1, 2x2, or other shapes) should be changed to light blue.
#
#
# to original grid overlay filter block tiles fill color remove black b reflect reflect remove color grid to block $0 blue teal negate boolean tile overlaps block $0 merge blocks tiles to blocks find tiles by black b $1
#
#
#
# create a left/ right mirror image of the input
#
#
# to min grid reflect grid to block $0
#
#
#
# create a left/ right mirror image of the input
#
#
# to original grid overlay reflect grid to block $0 negate boolean
#
#
#
# copy-paste the pattern in each corner. The pattern on the bottoms flips parallel to the top.
#
#
# to min grid reflect remove black b move reflect remove black b move reflect grid to block $0 3 south 3 east
#
#
#
# copy-paste the pattern in each corner. The pattern on the bottoms flips parallel to the top.
#
#
# to min grid reflect remove black b move reflect reflect remove black b move reflect grid to block $0 3 east 3 south
#
#
#
# flip the input grid vertically
#
#
# to min grid reflect grid to block $0
#
#
#
# flip the input grid vertically
#
#
# to original grid overlay reflect grid to block $0 negate boolean
#
#
#
# copy the grid and reflect on the other half
#
#
# to min grid move reflect remove black b grid to block $0 3 east
#
#
#
# copy the grid and reflect on the other half
#
#
# to min grid box block remove black b move reflect grid to block $0 3 east
#
#
#
# fill in the area of the large section with red to make a rectangular section. Background remain the same color
#
#
# to original grid overlay replace color merge blocks find same color blocks $0 black red
#
#
#
# fill in the area of the large section with red to make a rectangular section. Background remain the same color
#
#
# to original grid overlay filter block tiles fill color first of sorted object list find same color blocks $0 get num tiles $0 red negate boolean tile overlaps block $0 merge blocks find same color blocks $1
#
#
#
# use light blue color to draw the border of the grid with only one cell as width Create a light blue border around the grid. So, any tiles that are touching the edges are filled in with light blue. The rest of the tiles remain black. create a light blue border around the grid. So, any squares that are touching the edges are filled in with light blue. The rest of the squares inside the light blue border remain black.
#
#
# to min grid filter block tiles fill color grid to block $0 teal is exterior $0
#
#
#
# use light blue color to draw the border of the grid with only one cell as width Create a light blue border around the grid. So, any tiles that are touching the edges are filled in with light blue. The rest of the tiles remain black. create a light blue border around the grid. So, any squares that are touching the edges are filled in with light blue. The rest of the squares inside the light blue border remain black.
#
#
# to original grid overlay filter block tiles fill color grid to block $0 nth primary color grid to block $0 8 is exterior $0
#
#
#
# place the input grid in the top 3x3 space and create a mirror image in the bottom 3x3 space.
#
#
# to min grid move reflect grid to block $0 3 south
#
#
#
# place the input grid in the top 3x3 space and create a mirror image in the bottom 3x3 space.
#
#
# to min grid box block remove black b move reflect grid to block $0 3 south
#
#
#
# copy one of the figures and just that figure copy one of the figures and just that figure.
#
#
# blocks to min grid filter blocks find same color blocks $0 is tile $0
#
#
#
# copy one of the figures and just that figure copy one of the figures and just that figure.
#
#
# to min grid singleton block filter blocks filter blocks find same color blocks $0 is symmetrical $0 is symmetrical $0
#
#
#
# The output is the colored shape inverted to the side.
#
#
# to min grid reflect remove black b grid to block $0 negate boolean
#
#
#
# The output is the colored shape inverted to the side.
#
#
# to min grid reflect remove color grid to block $0 black
#
#
#
# copy the input 3x3 multi-colored shape ontop of the gray square, this square comprises the MIDDLE of the 3x3 copy.
#
#
# blocks to original grid map tiles find tiles by black b $0 center block on tile first of sorted object list find blocks by inferred b $1 get num tiles $0 $0
#
#
#
# replicate one of the patterns in one of the corners. Bottom right, bottom left, top right, or top left.
#
#
# to min grid first of sorted object list find same color blocks $0 get num tiles $0 negate boolean has color grid to block $0 blue
#
#
#
# replicate one of the patterns in one of the corners. Bottom right, bottom left, top right, or top left.
#
#
# to min grid box block first of sorted object list find same color blocks $0 get num tiles $0 is interior get block center remove color grid to block $0 blue
#
#
#
# mirror the grid on the new grid.
#
#
# to min grid box block move reflect reflect reflect grid to block $0 3 south
#
#
#
# mirror the grid on the new grid.
#
#
# to min grid box block move box block move reflect grid to block $0 3 south 3 north
#
#
#
# make the grid the same size as the shape and the two colors are just like in the shape.
#
#
# to min grid first of sorted object list find same color blocks $0 get num tiles remove color $0 blue
#
#
#
# make the grid the same size as the shape and the two colors are just like in the shape.
#
#
# to min grid remove color first of sorted object list find same color blocks $0 get num tiles remove color $0 blue yellow
#
#
#
# copy the same colors in the same position. For every single grid in the input, it should be changed to a 3x3 of color each in the output. use the same colors in the same position.
#
#
# to min grid grow grid to block $0 2
#
#
#
# copy the same colors in the same position. For every single grid in the input, it should be changed to a 3x3 of color each in the output. use the same colors in the same position.
#
#
# to min grid grow merge blocks find same color blocks $0 2
#
#
#
# keep the color with the most squares and everything else should be gray.
#
#
# to original grid overlay fill color merge blocks find blocks by inferred b $0 grey
#
#
#
# keep the color with the most squares and everything else should be gray.
#
#
# to original grid overlay filter block tiles fill color merge blocks find blocks by inferred b $0 grey
#
#
#
# compare the squares in the top and bottom 4x4 square. If they match (both black or both color) make the output square black. If they do not match, make the output square green.
#
#
# overlap split blocks split grid $0 color logical $0 $1 green lxor
#
#
#
# compare the squares in the top and bottom 4x4 square. If they match (both black or both color) make the output square black. If they do not match, make the output square green.
#
#
# overlap split blocks split grid $0 touches any boundary move grid to block $0 1 south color logical $1 $0 green lxor
#
#
#
# fill the black spots with the exact same pattern that need to be filled in the original grid.
#
#
# to min grid filter block tiles remove black b reflect grid to block $0 negate boolean tile overlaps block $0 remove black b grid to block $1
#
#
#
# fill the black spots with the exact same pattern that need to be filled in the original grid.
#
#
# to min grid filter block tiles remove black b reflect reflect grid to block $0 negate boolean tile overlaps block $0 remove black b grid to block $1
#
#
#
# place the input design all the way on the left half and then duplicate the exact same design and colors on the right half. The final grid is two of the original grid next to each other.
#
#
# to min grid duplicate grid to block $0 east 1
#
#
#
# place the input design all the way on the left half and then duplicate the exact same design and colors on the right half. The final grid is two of the original grid next to each other.
#
#
# to min grid duplicate box block grid to block $0 east 1
#
#
#
# changed the grid and the color.
#
#
# blocks to original grid map blocks filter blocks find blocks by color $0 black negate boolean touches any boundary $0 fill color $0 blue
#
#
#
# make the pattern and if there is any more on the sides or any blue, fill in with black.
#
#
# to min grid remove color grid to block $0 blue
#
#
#
# make the pattern and if there is any more on the sides or any blue, fill in with black.
#
#
# blocks to min grid find blocks by inferred b $0 negate boolean
#
#
#
# Move colored square one line down and change to red.
#
#
# to original grid overlay move replace color grid to block $0 teal red 1 south
#
#
#
# Move colored square one line down and change to red.
#
#
# to original grid overlay filter block tiles fill color wrap block remove black b move grid to block $0 1 south invisible red is interior $0
#
#
#
# find the color with the most spaces colored and put that pattern into the 3x3.
#
#
# to min grid remove black b first of sorted object list find same color blocks $0 get num tiles $0
#
#
#
# find the color with the most spaces colored and put that pattern into the 3x3.
#
#
# to min grid remove color first of sorted object list find same color blocks $0 get num tiles $0 blue
#
#
#
# change the pattern to match the one colored square at the bottom and fill in the one square at the bottom to black.
#
#
# to original grid overlay filter block tiles fill color remove black b grid to block $0 nth primary color grid to block $0 2 negate boolean tile overlaps block $0 merge blocks tiles to blocks find tiles by black b $1
#
#
#
# change the pattern to match the one colored square at the bottom and fill in the one square at the bottom to black.
#
#
# to original grid overlay filter block tiles fill color remove black b reflect reflect grid to block $0 nth primary color grid to block $0 2 negate boolean tile overlaps block $0 merge blocks tiles to blocks find tiles by black b $1
#
#
#
# copy the 3x3 square from the input grid that has the most blue pixels.
#
#
# to min grid first of sorted object list find blocks by color $0 blue get num tiles $0
#
#
#
# copy the 3x3 square from the input grid that has the most blue pixels.
#
#
# to min grid first of sorted object list find blocks by inferred b $0 get num tiles remove color $0 blue
#
#
#
# color smaller shapes dark blue.
#
#
# to original grid overlay fill color merge blocks tiles to blocks find tiles by black b $0 blue
#
#
#
# color smaller shapes dark blue.
#
#
# to original grid overlay fill color merge blocks tiles to blocks find tiles by black b $0 negate boolean blue
#
#
#
# turn the not-orange color into light red.
#
#
# to min grid replace color grid to block $0 pink red
#
#
#
# turn the not-orange color into light red.
#
#
# to min grid replace color box block grid to block $0 pink red
#
#
#
# remove the yellow rectangles and replace the all of the yellow squares with the appropriate color in order to create a pattern that is both horizontally and vertically symmetrical.
#
#
# to min grid reflect remove color grid to block $0 yellow
#
#
#
# remove the yellow rectangles and replace the all of the yellow squares with the appropriate color in order to create a pattern that is both horizontally and vertically symmetrical.
#
#
# to min grid remove color reflect grid to block $0 negate boolean yellow
#
#
#
# color in the center of each gray square red, but make sure you leave a 1 square gray border around it (so if it's a 5x5 gray square, you would color a red 3x3 square inside it, leaving a gray border around the red square).
#
#
# to original grid overlay filter block tiles fill color merge blocks find blocks by inferred b $0 red is interior $0
#
#
#
# color in the center of each gray square red, but make sure you leave a 1 square gray border around it (so if it's a 5x5 gray square, you would color a red 3x3 square inside it, leaving a gray border around the red square).
#
#
# to original grid overlay filter block tiles fill color remove black b reflect reflect remove color grid to block $0 blue red is interior $0
#
#
#
# fully zoomed pattern of a highest color count among the gird.
#
#
# to min grid first of sorted object list find same color blocks $0 get num tiles $0
#
#
#
# fully zoomed pattern of a highest color count among the gird.
#
#
# to min grid remove black b first of sorted object list find same color blocks $0 get num tiles $0
#
#
#
# divide each block  into a 2x2 square in the same color as the original block. So, each block from the original input grid will become a 2x2 block of 4 squares of the same color as the original block.
#
#
# to min grid grow grid to block $0 1
#
#
#
# divide each block  into a 2x2 square in the same color as the original block. So, each block from the original input grid will become a 2x2 block of 4 squares of the same color as the original block.
#
#
# to min grid grow merge blocks find same color blocks $0 1
#
#
#
# replace yellow grid with grey.
#
#
# to min grid replace color grid to block $0 orange grey
#
#
#
# replace yellow grid with grey.
#
#
# to original grid overlay box block replace color grid to block $0 orange grey
#
#
#
# count the number of squares in the colored border and resize the output to that number. Then you color all the blocks to match the input.
#
#
# to min grid first of sorted object list filter blocks find same color blocks $0 is symmetrical $0 get num tiles $0
#
#
#
# count the number of squares in the colored border and resize the output to that number. Then you color all the blocks to match the input.
#
#
# to min grid first of sorted object list find same color blocks $0 get num tiles remove color grid to block $1 nth primary color $0 0 has color grid to block $0 maroon
#
#
#
# create a left-right mirror of pattern of the orange shape. make the pattern mirror as left-right with the same height and twice the row.
#
#
# to min grid move reflect grid to block $0 3 east
#
#
#
# create a left-right mirror of pattern of the orange shape. make the pattern mirror as left-right with the same height and twice the row.
#
#
# to min grid box block move reflect reflect reflect grid to block $0 3 east
#
#
#
# change every gray square and the 9 squares that go all around it into blue. change the gray blocks to blue and the squares that go around it to turn it into a blue block of 9.
#
#
# blocks to original grid map tiles find tiles by black b $0 fill color wrap block remove black b grid to block $1 blue blue
#
#
#
# change every gray square and the 9 squares that go all around it into blue. change the gray blocks to blue and the squares that go around it to turn it into a blue block of 9.
#
#
# to original grid overlay wrap block fill color merge blocks tiles to blocks find tiles by black b $0 blue blue
#
#
#
# consider the long input as two sections as 4x4 grids, consider that the two sections as one. then the leave that black spaces as black then point the colored blocks as green.
#
#
# overlap split blocks split grid $0 color logical $0 $1 green lor
#
#
#
# consider the long input as two sections as 4x4 grids, consider that the two sections as one. then the leave that black spaces as black then point the colored blocks as green.
#
#
# overlap split blocks split grid $0 color logical $1 $0 color logical $1 $0 green lor lor
#
#
#
# wherever you see a color other than black make squares below that color the same color down to the border.
#
#
# blocks to original grid map tiles find tiles by black b $0 extend towards until $0 south touches boundary tile to block $0 south
#
#
#
# wherever you see a color other than black make squares below that color the same color down to the border.
#
#
# to original grid overlay duplicate remove black b grid to block $0 south 6
#
#
#
# turn everything black, but keep the middle vertical line of colored squares.
#
#
# to min grid fill color merge blocks splitblocks to blocks split grid $0 nth primary color grid to block $0 0
#
#
#
# turn everything black, but keep the middle vertical line of colored squares.
#
#
# to min grid box block fill color merge blocks splitblocks to blocks split grid $0 nth primary color grid to block $0 0
#
#
#
# copy the input grid. Then, connect the 2x2 green square to any and all other colored squares which you can reach with a straight line. Use the color of the square to which you are connecting the 2x2 green square. Fill in all of the black squares between that square and the 2x2 green square. Leave the rest of the grid - including any colored square you can't reach with a straight line - as they are.
#
#
# blocks to original grid map tiles find tiles by black b $0 extend until touches block $0 first of sorted object list find same color blocks $1 get num tiles $0
#
#
#
# copy the input grid. Then, connect the 2x2 green square to any and all other colored squares which you can reach with a straight line. Use the color of the square to which you are connecting the 2x2 green square. Fill in all of the black squares between that square and the 2x2 green square. Leave the rest of the grid - including any colored square you can't reach with a straight line - as they are.
#
#
# blocks to original grid map tiles find tiles by black b $0 extend until touches block $0 first of sorted object list find blocks by inferred b $1 get num tiles remove color $0 yellow
#
#
#
# fill in the holes of the boxes with green, then black out the outlines of the boxes.
#
#
# to original grid overlay filter block tiles fill color merge blocks find same color blocks $0 green is interior $0
#
#
#
# fill in the holes of the boxes with green, then black out the outlines of the boxes.
#
#
# to original grid overlay filter block tiles fill color merge blocks find same color blocks $0 green negate boolean tile overlaps block $0 remove black b move reflect grid to block $1 1 south
#
#
#
# zoom into the different colored center block from the input grid and make it the only colored block.
#
#
# to min grid filter block tiles remove black b grid to block $0 is interior $0
#
#
#
# zoom into the different colored center block from the input grid and make it the only colored block.
#
#
# to min grid filter block tiles remove black b move grid to block $0 3 south is interior $0
#
#
#
# copy and paste the left-side of the input (the yellow side) onto the output grid. Then, draw the green pattern on the output grid on top of the yellow (do not copy and paste because the black will overwrite the yellow). Your output grid should now have green and yellow on a black background. Then, recolor each green and yellow square pink, so your output is only pink and black.
#
#
# overlap split blocks split grid $0 color logical $0 $1 pink lor
#
#
#
# copy and paste the left-side of the input (the yellow side) onto the output grid. Then, draw the green pattern on the output grid on top of the yellow (do not copy and paste because the black will overwrite the yellow). Your output grid should now have green and yellow on a black background. Then, recolor each green and yellow square pink, so your output is only pink and black.
#
#
# overlap split blocks split grid $0 color logical color logical $0 $1 pink lor $0 pink lor
#
#
#
# connect the magenta boxes that are directly vertical and horizontal to each other.
#
#
# blocks to original grid map tiles find tiles by black b $0 extend until touches block $0 first of sorted object list find same color blocks $1 get num tiles extend until touches block $1 $0
#
#
#
# Copy the colored shape but make it twice the size as the input shape.
#
#
# to min grid grow merge blocks find blocks by black b $0 1
#
#
#
# Copy the colored shape but make it twice the size as the input shape.
#
#
# to min grid grow box block remove black b grid to block $0 1
#
#
#
# reflect down side to top.
#
#
# to original grid overlay remove black b reflect grid to block $0
#
#
#
# reflect down side to top.
#
#
# to original grid overlay remove black b reflect filter block tiles grid to block $0
#
#
#
# copy the largest squared border including colored squares inside but make all colored squares the same color as interior squares.
#
#
# to min grid replace color first of sorted object list find same color blocks $0 get num tiles $0 nth primary color remove black b first of sorted object list find same color blocks $0 get num tiles $0 0 nth primary color remove black b first of sorted object list find same color blocks $0 get num tiles $0 0

# %%
class DummyModel():
    def __init__(self):
        pass
    
    def fit(self, training_data):
        pass
    
    def evaluate_likelihood(self, language, ground_truth_program):
        return 0.0

def leave_one_out_evaluation(task_to_data, model):
    print(f"Running leave one out evaluation on {len(task_to_data)} tasks.")
    tasks_to_likelihoods = dict()
    for task in task_to_data:
        language, ground_truth_program = task_to_data[task]
        training_tasks = {t : d for t, d in task_to_data.items() if t != task}
        model.fit(training_tasks)
        likelihood = model.evaluate_likelihood(language, ground_truth_program)
        tasks_to_likelihoods[task] = likelihood
    print(f"Average likelihood: {np.mean(list(tasks_to_likelihoods.values()))}")
    return tasks_to_likelihoods
        

tasks_to_likelihoods = leave_one_out_evaluation(task_to_data, DummyModel())
# Out:
# Running leave one out evaluation on 136 tasks.
# Average likelihood: 0.0

# %% [markdown]
# ### Large language model and linear prediction baseline

# %% [markdown]
# TODO:
# - Encode the natural language to vector
# - Fit a linear decoder from the natural language vector to unigram predictions
# - Convert the unigram scores into a unigram grammar
# - Evaluate the likelihood of a ground truth program under the grammar
# - Training and evaluation loop: we should have a leave one out prediction.

# %% [markdown]
# ### Language encoding utilities

# %%
demo_task = '67e8384a.json'
demo_program, demo_language = task_to_data[demo_task]
print(demo_language)

from transformers import pipeline, T5Tokenizer, TFT5EncoderModel
T5_MODEL = 't5-small' # Source: https://huggingface.co/transformers/pretrained_models.html 
ROBERTA_MODEL = 'distilroberta-base'
T5 = 't5'

class LMUnigramPredictionLinear():
    """Encodes natural language as 
    """
    def __init__(self, lm_model_name):
        self.lm_model_name = lm_model_name
        if T5 in self.lm_model_name:
            self.tokenizer = T5Tokenizer.from_pretrained(self.lm_model_name)
            self.t5_encoder_model = TFT5EncoderModel.from_pretrained(self.lm_model_name)
            self.featurizer = self._t5_featurizer_fn
        else:
            self.featurizer = pipeline('feature-extraction', self.lm_model_name)
            
    def _t5_featurizer_fn(self, language):
        """Featurizes batch of sentences using a mean over the tokens in each sentence.
        args:
            language: [array of N sentences]
        ret: numpy array of size N x <HIDDEN_STATE_DIM>
        """
        input_ids = self.tokenizer(language, return_tensors="tf", padding=True, truncation=True).input_ids  # Batch size 1
        outputs = self.t5_encoder_model(input_ids)
        last_hidden_states = outputs.last_hidden_state 
        reduced = tf.math.reduce_mean(last_hidden_states, axis=1)
        return reduced.numpy()
    
    def _featurize_programs(self, programs):
        
    
    def _featurize_language(self, language):
        outputs = self.featurizer(language)
        return outputs
    
    def fit(self, task_to_data):
        """
        task_to_data: dict from task_names to (program, language) for each task.
        """
        programs, language = zip(*task_to_data.values())
        featurized_language = self._featurize_language(language)
        print(featurized_language.shape)
        

model = LMUnigramPredictionLinear(T5_MODEL)
outputs = model._featurize_language([demo_language, demo_language])

model.fit(task_to_data)
# Out:
# copy-paste the pattern in each corner. The pattern on the bottoms flips parallel to the top.
# Some layers from the model checkpoint at t5-small were not used when initializing TFT5EncoderModel: ['decoder']
# - This IS expected if you are initializing TFT5EncoderModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFT5EncoderModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFT5EncoderModel were initialized from the model checkpoint at t5-small.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFT5EncoderModel for predictions without further training.
# (136, 512)

# %%
demo_program
# Out:
# '(lambda (to_min_grid (reflect (remove_black_b (move (reflect (remove_black_b (move (reflect (grid_to_block $0) true) 3 south true)) false) 3 east true)) true) true))'
